# %%
import fiftyone as fo
import fiftyone.zoo as foz
from fiftyone import ViewField as F

# %%
print(fo.list_datasets())
# Out:
# ['open-images-v7-validation-200', 'sv-common-v1']

# %%
dataset = foz.load_zoo_dataset(
    "open-images-v7",
    split="validation",
    dataset_name="sv-common-v1",
    classes=["Waste Container"],
    label_types=["detections"],
    max_samples=200,
    shuffle=True,
    seed=42,
)
# Out:
# Downloading split 'validation' to '/Users/luna/fiftyone/open-images-v7/validation' if necessary
# Ignoring invalid classes ['Waste Container']
# You can view the available classes via `fiftyone.utils.openimages.get_classes()`
# Necessary images already downloaded
# Existing download of split 'validation' is sufficient
# Loading existing dataset 'sv-common-v1'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
view = dataset.filter_labels(
    "ground_truth",
    F("IsDepiction") == False
)

# %%
session = fo.launch_app(view, auto=False)
# Out:
# Session launched. Run `session.show()` to open the App in a cell output.

# %%
session
# Out:
# Dataset:          sv-common-v1
# Media type:       image
# Num samples:      196
# Selected samples: 0
# Selected labels:  0
# Session URL:      http://localhost:5151/
# View stages:
#     1. FilterLabels(field='ground_truth', filter={'$eq': ['$$this.IsDepiction', False]}, only_matches=True, trajectories=False)
